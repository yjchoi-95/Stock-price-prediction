# %%
import pandas as pd

# %%
temp_df = pd.read_csv("stock_df_01.csv")

# %%
temp_df.head()
# Out:
#          date  kosdaq_close  kosdaq_vol  kosdaq_var  us-30_close    us-30_vol  \
# 0  2012-01-03        513.83    590990.0        1.39     12397.38  152560000.0
# 1  2012-01-04        516.30    652090.0        0.48     12418.42  145130000.0
# 2  2012-01-05        521.96    654300.0        1.10     12415.70  158440000.0
# 3  2012-01-06        518.94    626020.0       -0.58     12359.92  131120000.0
# 4  2012-01-09        520.28    617370.0        0.26     12392.69  122200000.0
#
#    us-30_var  us-spx-500_close  us-spx-500_var  nasdaq-composite_close  ...  \
# 0       1.47           1277.06            1.55                 2648.72  ...
# 1       0.17           1277.30            0.02                 2648.36  ...
# 2      -0.02           1281.06            0.29                 2669.86  ...
# 3      -0.45           1277.81           -0.25                 2674.22  ...
# 4       0.27           1280.70            0.23                 2676.56  ...
#
# ...

# %%
temp_df.loc[temp_df.date > "2018-01-01"].to_csv("temp_stock_df.csv", index = False)

# %%
temp_df = pd.read_csv("bond_df.csv")

# %%
temp_df.head()
# Out:
#          date  germany-1_close  germany-1_var  u.s.-1_close  u.s.-1_var  \
# 0  2022-03-08              NaN            NaN        1.0909        4.39
# 1  2022-03-07           -0.685          -2.84        1.0450       -0.45
# 2  2022-03-06              NaN            NaN        1.0497        2.01
# 3  2022-03-05              NaN            NaN           NaN         NaN
# 4  2022-03-04           -0.705           6.02        1.0290       -3.83
#
#    brazil-1_close  brazil-1_var  switzerland-1_close  switzerland-1_var  \
# 0             NaN           NaN                -0.62             -11.43
# 1          13.275          2.04                -0.70               0.00
# 2             NaN           NaN                  NaN                NaN
# 3             NaN           NaN                  NaN                NaN
# 4          13.010          0.00                -0.70               9.38
#
#    uk-1_close  ...  china-10_close  china-10_var  canada-10_close  \
# ...
