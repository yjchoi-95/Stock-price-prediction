# %% [markdown]
# ## Import

# %%
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from ngboost import NGBClassifier
from collections import Counter
from tqdm import tqdm
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, cohen_kappa_score

# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings(action='default')

# %% [markdown]
# ## Load

# %%
out_data_path = 'C:\\Users\\PC0\\Documents\\datasets\\stock_price\\'
data_path = 'C:\\Users\\PC0\\Documents\\GitHub\\Stock-price-prediction\\datasets\\'
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
stock_df = pd.read_csv(data_path + "stock_df_01.csv")

# %%
n_target = np.array(list(stock_df.target))
c_target = np.array(list(stock_df.c_target))

# %%
del stock_df['target']
del stock_df['c_target']

# %%
stock_df.shape
# Out:
# (2410, 372)

# %%
var_cols = [x for x in stock_df.columns if "var" in x]

# %%
stock_df.head()
# Out:
#          date  kosdaq_close  kosdaq_vol  kosdaq_var  us-30_close    us-30_vol  \
# 0  2012-01-03        513.83    590990.0        1.39     12397.38  152560000.0
# 1  2012-01-04        516.30    652090.0        0.48     12418.42  145130000.0
# 2  2012-01-05        521.96    654300.0        1.10     12415.70  158440000.0
# 3  2012-01-06        518.94    626020.0       -0.58     12359.92  131120000.0
# 4  2012-01-09        520.28    617370.0        0.26     12392.69  122200000.0
#
#    us-30_var  us-spx-500_close  us-spx-500_var  nasdaq-composite_close  ...  \
# 0       1.47           1277.06            1.55                 2648.72  ...
# 1       0.17           1277.30            0.02                 2648.36  ...
# 2      -0.02           1281.06            0.29                 2669.86  ...
# 3      -0.45           1277.81           -0.25                 2674.22  ...
# 4       0.27           1280.70            0.23                 2676.56  ...
#
#    영국_아연_close  영국_아연_vol  영국_아연_var  은_close  은_vol  은_var  영국_주석_close  \
# 0      1864.25     9410.0       1.83   29.533  140.0   4.88      19949.0
# 1      1856.50     8430.0      -0.42   29.063   70.0  -1.59      19555.0
# 2      1821.25     7720.0      -1.90   29.265   30.0   0.70      19814.0
# 3      1840.75     7120.0       1.07   28.653   80.0  -2.09      19807.0
# 4      1870.25     9620.0       1.60   28.749   60.0  -0.34      19746.0
#
#    영국_주석_var  미국_팔라듐_close  미국_팔라듐_var
# 0       4.13         664.8        1.42
# 1      -1.98         649.9       -2.24
# 2       1.32         640.4       -1.46
# 3      -0.04         616.1       -3.79
# 4      -0.31         620.0        0.63
#
# [5 rows x 372 columns]

# %% [markdown]
# ## Modeling

# %% [markdown]
# * label portion 탐색

# %%
Counter(c_target)
# Out:
# Counter({'Down': 1136, 'Up': 1274})

# %%
1274/(1136+1274)
# Out:
# 0.5286307053941909

# %% [markdown]
# * baseline modeling - moving window

# %%
# temp_x = stock_df.loc[:, var_cols]
temp_x = stock_df.iloc[:, 1:]

# %%
temp_x.head()
# Out:
#    kosdaq_close  kosdaq_vol  kosdaq_var  us-30_close    us-30_vol  us-30_var  \
# 0        513.83    590990.0        1.39     12397.38  152560000.0       1.47
# 1        516.30    652090.0        0.48     12418.42  145130000.0       0.17
# 2        521.96    654300.0        1.10     12415.70  158440000.0      -0.02
# 3        518.94    626020.0       -0.58     12359.92  131120000.0      -0.45
# 4        520.28    617370.0        0.26     12392.69  122200000.0       0.27
#
#    us-spx-500_close  us-spx-500_var  nasdaq-composite_close  \
# 0           1277.06            1.55                 2648.72
# 1           1277.30            0.02                 2648.36
# 2           1281.06            0.29                 2669.86
# 3           1277.81           -0.25                 2674.22
# 4           1280.70            0.23                 2676.56
#
#    nasdaq-composite_vol  ...  영국_아연_close  영국_아연_vol  영국_아연_var  은_close  \
# 0           411790000.0  ...      1864.25     9410.0       1.83   29.533
# 1           411090000.0  ...      1856.50     8430.0      -0.42   29.063
# 2           442080000.0  ...      1821.25     7720.0      -1.90   29.265
# 3           412310000.0  ...      1840.75     7120.0       1.07   28.653
# 4           447700000.0  ...      1870.25     9620.0       1.60   28.749
#
#    은_vol  은_var  영국_주석_close  영국_주석_var  미국_팔라듐_close  미국_팔라듐_var
# 0  140.0   4.88      19949.0       4.13         664.8        1.42
# 1   70.0  -1.59      19555.0      -1.98         649.9       -2.24
# 2   30.0   0.70      19814.0       1.32         640.4       -1.46
# 3   80.0  -2.09      19807.0      -0.04         616.1       -3.79
# 4   60.0  -0.34      19746.0      -0.31         620.0        0.63
#
# [5 rows x 371 columns]

# %%
train_volum = 100
train_start_idx = 0
sample_days = 5

data = temp_x

model_xgb = XGBClassifier()
model_lgbm = LGBMClassifier()
model_ngb = NGBClassifier(verbose = False)
model_cat = CatBoostClassifier(verbose = False)

model = model_ngb
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
c_target_num = np.where(c_target == "Up", 1, 0)
c_target_num = pd.DataFrame(c_target_num)

# %%
pred_dict = {}

# %%
train_end_idx = train_start_idx + train_volum
test_start_idx = train_end_idx + 1

whole_predict = []
whole_proba = []
whole_truth = []
whole_acc = []

print("Start Fitting..")
for _ in tqdm(range(data.shape[0] - (train_volum + 1))) :
    '''
    model_ngb = NGBClassifier(verbose = False)
    model = model_ngb
    '''
    
    temp_train_x = data.loc[train_start_idx:train_end_idx,:]
    temp_train_y = c_target_num.loc[train_start_idx:train_end_idx]
    temp_test_x = data.loc[test_start_idx:test_start_idx,:]
    temp_test_y = c_target_num.loc[test_start_idx]

    # append sample
    temp_train_x = temp_train_x.append(temp_train_x.loc[(train_end_idx - sample_days):])
    temp_train_y = temp_train_y.append(temp_train_y.loc[(train_end_idx - sample_days):])

    # fitting
    model.fit(temp_train_x,temp_train_y)
    # predict
    predict_value = model.predict(temp_test_x)
    whole_proba.append(model.predict_proba(temp_test_x)[0])

    # save acc
    pred_dict[stock_df.date[test_start_idx]] = predict_value[0]
    whole_predict.append(predict_value[0])
    whole_truth.append(temp_test_y.iloc[0])

    train_start_idx += 1
    train_end_idx = train_start_idx + train_volum
    test_start_idx = train_end_idx + 1

print("Finish")
# Out:
#   0%|                                                                                         | 0/2309 [00:00<?, ?it/s]
# Start Fitting..
# C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#   0%|                                                                               | 1/2309 [00:09<5:51:12,  9.13s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#   0%|                                                                               | 2/2309 [00:18<5:48:06,  9.05s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#   0%
/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#  99%|███████████████████████████████████████████████████████████████████████████▌| 2295/2309 [4:48:33<02:06,  9.04s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#  99%|███████████████████████████████████████████████████████████████████████████▌| 2296/2309 [4:48:42<01:57,  9.07s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#  99%|███████████████████████████████████████████████████████████████████████████▌| 2297/2309 [4:48:51<01:48,  9.02s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▋| 2298/2309 [4:49:00<01:38,  8.98s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▋| 2299/2309 [4:49:09<01:29,  9.00s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▋| 2300/2309 [4:49:18<01:20,  8.98s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▋| 2301/2309 [4:49:27<01:11,  8.93s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▊| 2302/2309 [4:49:36<01:02,  8.90s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▊| 2303/2309 [4:49:45<00:53,  8.88s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▊| 2304/2309 [4:49:53<00:44,  8.86s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▊| 2305/2309 [4:50:02<00:35,  8.84s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▉| 2306/2309 [4:50:11<00:26,  8.84s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▉| 2307/2309 [4:50:20<00:17,  8.85s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|███████████████████████████████████████████████████████████████████████████▉| 2308/2309 [4:50:29<00:08,  8.91s/it]C:\Users\PC0\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 100%|████████████████████████████████████████████████████████████████████████████| 2309/2309 [4:50:38<00:00,  7.55s/it]
# Finish

# %% [markdown]
# * ngboost performance

# %%
accuracy_score(whole_truth, whole_predict)
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.5448245993936769

# %%
precision_score(whole_truth, whole_predict)
# Out:
# 0.5668238993710691

# %%
recall_score(whole_truth, whole_predict)
# Out:
# 0.5904995904995906

# %%
f1_score(whole_truth, whole_predict)
# Out:
# 0.5784195748094665

# %%
cohen_kappa_score(whole_truth, whole_predict)
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:608: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   w_mat = np.ones([n_classes, n_classes], dtype=np.int)
# 0.0842809344356259

# %%
# proba check

zero_prob = [x[0] for x in whole_proba]
one_prob = [x[1] for x in whole_proba]

tr = 0.9

zero_idx = np.where(np.array(zero_prob) > tr)[0]
one_idx = np.where(np.array(one_prob) > tr)[0]

# %%
1 - np.mean(np.array(whole_truth)[zero_idx])
# Out:
# 0.5427215189873418

# %%
np.mean(np.array(whole_truth)[one_idx])
# Out:
# 0.5737704918032787

# %% [markdown]
# * baseline modeling - stacked sample

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
train_volum = 100
train_start_idx = 0
sample_days = 5

data = temp_x

model_xgb = XGBClassifier()
model_lgbm = LGBMClassifier()
model_ngb = NGBClassifier()
model_cat = CatBoostClassifier(verbose = False)

model = model_lgbm

# %%
c_target_num = np.where(c_target == "Up", 1, 0)
c_target_num = pd.DataFrame(c_target_num)

# %%
pred_dict = {}

# %%
beta = 0.999

# %%
train_end_idx = train_start_idx + train_volum
test_start_idx = train_end_idx + 1

whole_predict = []
whole_proba = []
whole_truth = []
whole_acc = []

print("Start Fitting..")
for _ in tqdm(range(data.shape[0] - (train_volum + 1))) :
    temp_train_x = data.loc[:train_end_idx,:]
    temp_train_y = c_target_num.loc[:train_end_idx]
    temp_test_x = data.loc[test_start_idx:test_start_idx,:]
    temp_test_y = c_target_num.loc[test_start_idx]

    # append sample
    temp_train_x = temp_train_x.append(temp_train_x.loc[(train_end_idx - sample_days):])
    temp_train_y = temp_train_y.append(temp_train_y.loc[(train_end_idx - sample_days):])
    
    sim_mat = cosine_similarity(np.array(temp_train_x))
    
    #sample_w = [beta ** x for x in range((temp_train_x.shape[0]), 0, -1)]
    #sample_w = np.array(sample_w) + 1-np.mean(sample_w)
    
    # fitting
    #model.fit(temp_train_x,temp_train_y, sample_weight=sample_w)
    model.fit(temp_train_x,temp_train_y, sample_weight=sim_mat[-1])
    #model.fit(temp_train_x,temp_train_y)
    
    # predict
    predict_value = model.predict(temp_test_x)
    whole_proba.append(model.predict_proba(temp_test_x)[0])

    # save acc
    pred_dict[stock_df.date[test_start_idx]] = predict_value[0]
    whole_predict.append(predict_value[0])
    whole_truth.append(temp_test_y.iloc[0])

    train_start_idx += 1
    train_end_idx = train_start_idx + train_volum
    test_start_idx = train_end_idx + 1

print("Finish")

# %% [markdown]
# * lightgbm performance - with sample weights using cosine sim

# %%
accuracy_score(whole_truth, whole_predict)
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.6011260285838025

# %%
precision_score(whole_truth, whole_predict)
# Out:
# 0.6141552511415526

# %%
recall_score(whole_truth, whole_predict)
# Out:
# 0.6609336609336609

# %%
f1_score(whole_truth, whole_predict)
# Out:
# 0.6366863905325445

# %%
cohen_kappa_score(whole_truth, whole_predict)
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:608: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   w_mat = np.ones([n_classes, n_classes], dtype=np.int)
# 0.19585279333506522

# %%
# proba check

zero_prob = [x[0] for x in whole_proba]
one_prob = [x[1] for x in whole_proba]

tr = 0.9

zero_idx = np.where(np.array(zero_prob) > tr)[0]
one_idx = np.where(np.array(one_prob) > tr)[0]

# %%
1 - np.mean(np.array(whole_truth)[zero_idx])
# Out:
# 0.7035714285714285

# %%
np.mean(np.array(whole_truth)[one_idx])
# Out:
# 0.6814988290398126

# %% [markdown]
# * lightgbm performance - with sample weights 0.999 beta adjust

# %%
accuracy_score(whole_truth, whole_predict)
# Out:
# 0.6145517540060632

# %%
precision_score(whole_truth, whole_predict)
# Out:
# 0.6258555133079848

# %%
recall_score(whole_truth, whole_predict)
# Out:
# 0.674037674037674

# %%
f1_score(whole_truth, whole_predict)
# Out:
# 0.6490536277602523

# %%
cohen_kappa_score(whole_truth, whole_predict)
# Out:
# 0.22288055410804897

# %%
# proba check

zero_prob = [x[0] for x in whole_proba]
one_prob = [x[1] for x in whole_proba]

tr = 0.9

zero_idx = np.where(np.array(zero_prob) > tr)[0]
one_idx = np.where(np.array(one_prob) > tr)[0]

# %%
1 - np.mean(np.array(whole_truth)[zero_idx])
# Out:
# 0.7320754716981133

# %%
np.mean(np.array(whole_truth)[one_idx])
# Out:
# 0.6857142857142857

# %% [markdown]
# * lightgbm performance - with sample weights 0.9975 beta

# %%
accuracy_score(whole_truth, whole_predict)
# Out:
# 0.6007020623080298

# %%
precision_score(whole_truth, whole_predict)
# Out:
# 0.6188951160928743

# %%
recall_score(whole_truth, whole_predict)
# Out:
# 0.6404308202154101

# %%
f1_score(whole_truth, whole_predict)
# Out:
# 0.6294788273615636

# %%
cohen_kappa_score(whole_truth, whole_predict)
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:608: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   w_mat = np.ones([n_classes, n_classes], dtype=np.int)
# 0.19683223747142864

# %%
# proba check

zero_prob = [x[0] for x in whole_proba]
one_prob = [x[1] for x in whole_proba]

tr = 0.9

zero_idx = np.where(np.array(zero_prob) > tr)[0]
one_idx = np.where(np.array(one_prob) > tr)[0]

# %%
1 - np.mean(np.array(whole_truth)[zero_idx])
# Out:
# 0.7239263803680982

# %%
np.mean(np.array(whole_truth)[one_idx])
# Out:
# 0.6784968684759917

# %% [markdown]
# * lightgbm performance - W/O sample weights

# %%
accuracy_score(whole_truth, whole_predict)
# Out:
# 0.6071892594196622

# %%
precision_score(whole_truth, whole_predict)
# Out:
# 0.6218944099378882

# %%
recall_score(whole_truth, whole_predict)
# Out:
# 0.6560196560196561

# %%
f1_score(whole_truth, whole_predict)
# Out:
# 0.638501394978079

# %%
cohen_kappa_score(whole_truth, whole_predict)
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:608: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   w_mat = np.ones([n_classes, n_classes], dtype=np.int)
# 0.20911070115578445

# %%
# proba check

zero_prob = [x[0] for x in whole_proba]
one_prob = [x[1] for x in whole_proba]

tr = 0.9

zero_idx = np.where(np.array(zero_prob) > tr)[0]
one_idx = np.where(np.array(one_prob) > tr)[0]

# %%
1 - np.mean(np.array(whole_truth)[zero_idx])
# Out:
# 0.7175572519083969

# %%
np.mean(np.array(whole_truth)[one_idx])
# Out:
# 0.676056338028169

# %% [markdown]
# * catboost performance

# %%
accuracy_score(whole_truth, whole_predict)
# Out:
# 0.5747076656561282

# %%
precision_score(whole_truth, whole_predict)
# Out:
# 0.5897821187077386

# %%
recall_score(whole_truth, whole_predict)
# Out:
# 0.642915642915643

# %%
f1_score(whole_truth, whole_predict)
# Out:
# 0.6152037617554859

# %%
cohen_kappa_score(whole_truth, whole_predict)
# Out:
# 0.14185854111584528

# %%
# proba check

zero_prob = [x[0] for x in whole_proba]
one_prob = [x[1] for x in whole_proba]

tr = 0.9

zero_idx = np.where(np.array(zero_prob) > tr)[0]
one_idx = np.where(np.array(one_prob) > tr)[0]

# %%
1 - np.mean(np.array(whole_truth)[zero_idx])
# Out:
# 1.0

# %%
np.mean(np.array(whole_truth)[one_idx])
# Out:
# 0.6923076923076923

# %% [markdown]
# * xgboost performance

# %%
accuracy_score(whole_truth, whole_predict)
# Out:
# 0.5574738755111313

# %%
precision_score(whole_truth, whole_predict)
# Out:
# 0.5817427385892117

# %%
recall_score(whole_truth, whole_predict)
# Out:
# 0.5986336464560205

# %%
f1_score(whole_truth, whole_predict)
# Out:
# 0.5900673400673402

# %%
cohen_kappa_score(whole_truth, whole_predict)
# Out:
# C:\Users\PC0\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:608: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   w_mat = np.ones([n_classes, n_classes], dtype=np.int)
# 0.10953093418557103

# %%
# proba check

zero_prob = [x[0] for x in whole_proba]
one_prob = [x[1] for x in whole_proba]

tr = 0.9

zero_idx = np.where(np.array(zero_prob) > tr)[0]
one_idx = np.where(np.array(one_prob) > tr)[0]

# %%
1 - np.mean(np.array(whole_truth)[zero_idx])
# Out:
# 0.6126984126984127

# %%
np.mean(np.array(whole_truth)[one_idx])
# Out:
# 0.6202290076335878
